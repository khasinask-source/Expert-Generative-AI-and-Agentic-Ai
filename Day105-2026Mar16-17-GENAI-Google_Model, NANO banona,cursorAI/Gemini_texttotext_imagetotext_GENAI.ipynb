# %%
pip install -U google-genai
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.3/52.3 kB 2.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 733.5/733.5 kB 16.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: google-genai
#     Found existing installation: google-genai 1.66.0
#     Uninstalling google-genai-1.66.0:
#       Successfully uninstalled google-genai-1.66.0
# ...

# %%
import os
os.environ['GEMINI_API_KEY'] = 'AIzaSyChDHyv18gxll5EeOtbAthhGFxLoSV9yrA'

# %%
import google.generativeai as genai
genai.configure(api_key=os.environ['GEMINI_API_KEY'])

# %%
model = genai.GenerativeModel("gemini-3.1-flash-lite-preview")

# %%
response = model.generate_content

# %%
response = model.generate_content("Tabular form difference of AI and GenAI")
print(response.text)
# Out:
# The primary difference between **AI (Artificial Intelligence)** and **GenAI (Generative AI)** lies in their core objective: AI is designed to **analyze, classify, and predict** based on existing data, whereas GenAI is designed to **create new content** that mimics human output.
#
# Here is the difference in tabular form:
#
# | Feature | AI (Traditional/Discriminative) | GenAI (Generative AI) |
# | :--- | :--- | :--- |
# | **Primary Goal** | To analyze, categorize, or predict outcomes. | To generate new, original content. |
# | **Output Type** | Decisions, labels, predictions, or classifications. | Text, images, music, code, or video. |
# | **Functionality** | Acts as a "Judge" (discriminates data). | Acts as a "Creator" (generates data). |
# | **Relationship** | The broad field (the umbrella term). | A specialized subset of AI. |
# | **Data Usage** | Learns patterns to identify trends or solve specific tasks. | Learns patterns to produce new data similar to the training set. |
# ...

# %%
import pathlib
import textwrap
import google.generativeai as genai
from IPython.display import display
from IPython.display import Markdown
def to_markdown(text):
  text = text.replace('a','*')
  return Markdown(textwrap.indent(text,'>',predicate=lambda _: True))

# %%
for m in genai.list_models():
    if 'generateContent' in m.supported_generation_methods:
        print(m.name)
# Out:
# models/gemini-2.5-flash
# models/gemini-2.5-pro
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-2.5-flash-preview-tts
# models/gemini-2.5-pro-preview-tts
# models/gemma-3-1b-it
# models/gemma-3-4b-it
# models/gemma-3-12b-it
# models/gemma-3-27b-it
# models/gemma-3n-e4b-it
# models/gemma-3n-e2b-it
# models/gemini-flash-latest
# models/gemini-flash-lite-latest
# models/gemini-pro-latest
# models/gemini-2.5-flash-lite
# models/gemini-2.5-flash-image
# models/gemini-2.5-flash-lite-preview-09-2025
# models/gemini-3-pro-preview
# models/gemini-3-flash-preview
# models/gemini-3.1-pro-preview
# models/gemini-3.1-pro-preview-customtools
# models/gemini-3.1-flash-lite-preview
# models/gemini-3-pro-image-preview
# models/nano-banana-pro-preview
# models/gemini-3.1-flash-image-preview
# models/gemini-robotics-er-1.5-preview
# models/gemini-2.5-computer-use-preview-10-2025
# ...

# %%
#model=genai.GenerativeModel('gemini-2.5-pro-exp-03-25')
model=genai.GenerativeModel('gemini-3.1-flash-preview')
model=genai.GenerativeModel('gemini-2.0-flash-exp-image-generation')

# %%
# %%time
model = genai.GenerativeModel('gemini-3.1-flash-lite-preview')
response = model.generate_content('create a table for summarazie to a kid about datascience vs machine learning')
# Out:
# CPU times: user 115 ms, sys: 17.1 ms, total: 132 ms
# Wall time: 18.6 s

# %%
to_markdown(response.text)
# Out:
# >Here is * simple t*ble to help * kid underst*nd the difference between D*t* Science *nd M*chine Le*rning.
# >
# >### The "Detective" vs. The "Robot Tr*iner"
# >
# >| Fe*ture | D*t* Science (The Detective) | M*chine Le*rning (The Robot Tr*iner) |
# >| :--- | :--- | :--- |
# >| **M*in Job** | Looking for clues in big piles of inform*tion to *nswer questions. | Te*ching * computer to le*rn from p*tterns so it c*n m*ke decisions. |
# >| **Go*l** | To underst*nd "Wh*t h*ppened?" *nd "Why?" | To predict "Wh*t will h*ppen next?" |
# >| **Tools Used** | Ch*rts, gr*phs, *nd detective-style reports. | M*th rules *nd "br*in-like" computer progr*ms. |
# >| **Think of it *s...** | A detective solving * mystery using clues. | A te*cher tr*ining * robot to pl*y * g*me. |
# >| **Ex*mple** | Checking school lunch numbers to see which food kids like best. | Te*ching * computer to recognize * picture of * c*t. |
# >
# >***
# >
# >### In simple terms:
# >
# ...

# %%
response.prompt_feedback

# %%
response.candidates
# Out:
# [content {
#   parts {
# ...

# %%
for chunk in response:
  print(chunk.text)
# Out:
# Here is a simple table to help a kid understand the difference between Data Science and Machine Learning.
#
# ### The "Detective" vs. The "Robot Trainer"
#
# | Feature | Data Science (The Detective) | Machine Learning (The Robot Trainer) |
# | :--- | :--- | :--- |
# | **Main Job** | Looking for clues in big piles of information to answer questions. | Teaching a computer to learn from patterns so it can make decisions. |
# | **Goal** | To understand "What happened?" and "Why?" | To predict "What will happen next?" |
# | **Tools Used** | Charts, graphs, and detective-style reports. | Math rules and "brain-like" computer programs. |
# | **Think of it as...** | A detective solving a mystery using clues. | A teacher training a robot to play a game. |
# | **Example** | Checking school lunch numbers to see which food kids like best. | Teaching a computer to recognize a picture of a cat. |
#
# ***
#
# ### In simple terms:
#
# ...

# %%
#TEXT MODEL WE BUILT USING DIFFERENT GEMINI MODELS & LATEST MODELS

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import PIL.Image
img = PIL.Image.open(r'/content/wallpaper.png')
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1536x1024>

# %%
model = genai.GenerativeModel('models/gemini-3.1-flash-lite-preview')

# %%
import pathlib
import textwrap
import google.generativeai as genai
from IPython.display import display
from IPython.display import Markdown

def to_markdown(text):
  text = text.replace('•', '  *')
  return Markdown(textwrap.indent(text, '> ', predicate=lambda _: True))

# %%
response = model.generate_content(img)
to_markdown(response.text)
# Out:
# > This image appears to be a promotional graphic for an educational institution or initiative called "AI9 CAMPUS: THE INDIAN SCHOOL."
# >
# > Here is a breakdown of the visual elements presented:
# >
# > *   **Central Theme:** The imagery heavily emphasizes the fusion of technology, artificial intelligence, and education. The central logo depicts a shield split into two halves: one side resembles a human brain (symbolizing intellect), and the other resembles a digital circuit (symbolizing technology/AI).
# > *   **Indian Identity:** The Indian national flag is prominently featured in the top left and draped behind the logo, while a glowing map of India is shown on the globe in the background.
# > *   **Educational Symbols:** Traditional learning tools are combined with futuristic ones. You can see stacks of books, an open book with a sprouting plant (symbolizing growth/knowledge), a pen, and a microscope.
# ...

# %%
response = model.generate_content([
    "write a script for 5sec instagram shoot to gain good view",
    img
], stream=True)

# %%
response.resolve()
to_markdown(response.text)
# Out:
# > To get high views on a 5-second Reel, you need **fast pacing, a high-quality visual hook, and curiosity.** Since your image is tech-focused and futuristic, you should lean into the "Future of Education" vibe.
# >
# > Here are three script options for your 5-second Reel:
# >
# > ### Option 1: The "Transformation" Hook (Best for Engagement)
# > *   **Visual:** Start with a blurry, slightly grainy close-up of a traditional book. A digital "glitch" effect snaps the screen into your high-resolution AI9 Campus image.
# > *   **Audio:** A fast, sharp "Whoosh" sound followed by a futuristic "ping" or synth beat.
# > *   **Text Overlay:**
# >     *   0s - 2s: "Is this the future of Indian education? 🇮🇳"
# >     *   2s - 5s: "Welcome to AI9 Campus. 🤖"
# > *   **Why it works:** It forces the viewer to watch the transition and creates a "What is this?" curiosity gap.
# >
# > ### Option 2: The "Rapid Fire" Aesthetic (Best for Viral Reach)
# ...
